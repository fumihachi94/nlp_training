# %% [markdown]
# # 01 NNの基本
#
# 参考サイト：
# [ライブラリーを使わずにPythonでニューラルネットワークを構築してみる - Qiita](https://qiita.com/kiminaka/items/9ae195739093277490fe)
#
# 補足：
# sklearnのmake_moonsデータ・セットについては[scikit-learn – make_moons – TauStation](http://taustation.com/scikit-learn-make_moons/)に詳しくのっています。

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import datasets
from sklearn import linear_model

# %% [markdown]
# ### 分類用サンプルデータの生成
# 毎回同じ結果となるようにランダムのシードを0に設定してあります。

# %%
np.random.seed(0)
x,y = datasets.make_moons(200, noise=0.20)
plt.scatter(x[:,0], x[:,1], s=40, c=y, cmap=plt.cm.Spectral)

# %% [markdown]
# ### ロジスティック回帰による分類
#
# clf: classifier →　分類機

# %%
clf = linear_model.LogisticRegressionCV()
clf.fit(x,y)

x_min, x_max = x[:, 0].min() - .5, x[:, 0].max() + .5
y_min, y_max = x[:, 1].min() - .5, x[:, 1].max() + .5
h = 0.01
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
z = z.reshape(xx.shape)
plt.contourf(xx, yy, z, cmap=plt.cm.Blues)
plt.scatter(x[:,0], x[:,1], s=40, c=y, cmap=plt.cm.Spectral)
plt.show()
